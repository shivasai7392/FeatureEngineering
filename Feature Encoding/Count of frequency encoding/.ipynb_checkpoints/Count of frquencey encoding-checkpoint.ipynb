# %%
import pandas as pd
import numpy as np

# data is from 'http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'

# %%
data = pd.read_csv("/home/shivasai7392/Desktop/DS/Datasets/Adult/adult.csv")

# %%
data.head()
# Out:
#    Unnamed: 0         Employment      Degree       Marital_Status  \
# 0           0          State-gov   Bachelors        Never-married
# 1           1   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2           2            Private     HS-grad             Divorced
# 3           3            Private        11th   Married-civ-spouse
# 4           4            Private   Bachelors   Married-civ-spouse
#
#           Designation      Family_job   Color      Sex         Country
# 0        Adm-clerical   Not-in-family   White     Male   United-States
# 1     Exec-managerial         Husband   White     Male   United-States
# 2   Handlers-cleaners   Not-in-family   White     Male   United-States
# 3   Handlers-cleaners         Husband   Black     Male   United-States
# 4      Prof-specialty            Wife   Black   Female            Cuba

# %%
data.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
data.head()
# Out:
#           Employment      Degree       Marital_Status         Designation  \
# 0          State-gov   Bachelors        Never-married        Adm-clerical
# 1   Self-emp-not-inc   Bachelors   Married-civ-spouse     Exec-managerial
# 2            Private     HS-grad             Divorced   Handlers-cleaners
# 3            Private        11th   Married-civ-spouse   Handlers-cleaners
# 4            Private   Bachelors   Married-civ-spouse      Prof-specialty
#
#        Family_job   Color      Sex         Country
# 0   Not-in-family   White     Male   United-States
# 1         Husband   White     Male   United-States
# 2   Not-in-family   White     Male   United-States
# 3         Husband   Black     Male   United-States
# 4            Wife   Black   Female            Cuba

# %%
 for i in data.columns:
        print("{} {}".format(i,len(data[i].unique())))
# Out:
# Employment 9
# Degree 16
# Marital_Status 7
# Designation 15
# Family_job 6
# Color 5
# Sex 2
# Country 42

# %%
coutrymapper = data.Country.value_counts().to_dict()

# %%
data["Coutry_count"] = data.Country.map(coutrymapper)

# %%
data.head()
# Out:
#           Employment      Degree       Marital_Status         Designation  \
# 0          State-gov   Bachelors        Never-married        Adm-clerical
# 1   Self-emp-not-inc   Bachelors   Married-civ-spouse     Exec-managerial
# 2            Private     HS-grad             Divorced   Handlers-cleaners
# 3            Private        11th   Married-civ-spouse   Handlers-cleaners
# 4            Private   Bachelors   Married-civ-spouse      Prof-specialty
#
#        Family_job   Color      Sex         Country  Coutry_count
# 0   Not-in-family   White     Male   United-States         29170
# 1         Husband   White     Male   United-States         29170
# 2   Not-in-family   White     Male   United-States         29170
# 3         Husband   Black     Male   United-States         29170
# 4            Wife   Black   Female            Cuba            95

# %%
data.drop("Country",axis = 1,inplace=True)

# %%
data.head()
# Out:
#           Employment      Degree       Marital_Status         Designation  \
# 0          State-gov   Bachelors        Never-married        Adm-clerical
# 1   Self-emp-not-inc   Bachelors   Married-civ-spouse     Exec-managerial
# 2            Private     HS-grad             Divorced   Handlers-cleaners
# 3            Private        11th   Married-civ-spouse   Handlers-cleaners
# 4            Private   Bachelors   Married-civ-spouse      Prof-specialty
#
#        Family_job   Color      Sex  Coutry_count
# 0   Not-in-family   White     Male         29170
# 1         Husband   White     Male         29170
# 2   Not-in-family   White     Male         29170
# 3         Husband   Black     Male         29170
# 4            Wife   Black   Female            95

# %% [markdown]
# #### Advantages
#
# 1.easy to implement
# 2.no curse of dimensionality problem
#
# #### Disadvantages
#
# 1.loose of information if two categrories count is same
